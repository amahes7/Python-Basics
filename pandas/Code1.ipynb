# %%
import pandas

# %%
df= pandas.read_csv("E:\Sem-1 UIC\IDS-570\Session 3\cars.csv")

# %%
df
# Out:
#       year model   price  mileage   color transmission       date
# 0    2,011   SEL  21,992    7,413  Yellow         AUTO   2-May-13
# 1    2,011   SEL  20,995   10,926    Gray         AUTO   3-May-13
# 2    2,011   SEL  19,995    7,351  Silver         AUTO   4-May-13
# 3    2,011   SEL  17,809   11,613    Gray         AUTO   5-May-13
# 4    2,012    SE  17,500    8,367   White         AUTO   6-May-13
# 5    2,010   SEL  17,495   25,125  Silver         AUTO   7-May-13
# 6    2,011   SEL  17,000   27,393    Blue         AUTO   8-May-13
# 7    2,010   SEL  16,995   21,026  Silver         AUTO   9-May-13
# 8    2,011   SES  16,995   32,655  Silver         AUTO  10-May-13
# 9    2,010   SES  16,995   36,116  Silver         AUTO  11-May-13
# 10   2,010   SES  16,995   40,539   Black         AUTO  12-May-13
# 11   2,011   SES  16,992    9,199  Silver         AUTO  13-May-13
# 12   2,011   SEL  16,950    9,388   Green         AUTO  14-May-13
# ...
